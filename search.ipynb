# %%
import random

class State:

    def __init__(self, prices=None, enemy_prices=None):
        self.prices = prices if prices != None else [0]*9
        self.enemy_prices = enemy_prices if enemy_prices != None else [0]*9

    def price_count(self, prices):
        count=0
        for i in prices:
            if i == 1:
                count += 1
            
        return count
    
    def is_lose(self):
        def is_comp(x, y, dx, dy):
            for k in range(3):
                if y < 0 or 2 < y or x < 0 or 2 < x or self.enemy_prices[x + y * 3] == 0:
                    return False
                
                x = x + dx
                y = y + dy
            return True
        
        if is_comp(0, 0, 1, 1) or is_comp(0, 2, 1, -1):
            return True
        for i in range(3):
            if is_comp(0, i, 1, 0) or is_comp(i, 0, 0, 1):
                return True
        return False
    
    def is_draw(self):
        return self.price_count(self.prices) + self.price_count(self.enemy_prices) == 9
    
    def is_done(self):
        return self.is_lose() or self.is_draw()
    
    def next(self, action):
        prices = self.prices.copy()
        prices[action] = 1
        return State(self.enemy_prices, prices)
    
    def legal_actions(self):
        actions = []
        for i in range(9):
            if self.prices[i] == 0 and self.enemy_prices[i] == 0:
                actions.append(i)
        return actions
    
    def is_first_player(self):
        return self.price_count(self.prices) == self.price_count(self.enemy_prices)
    
    def __str__(self):
        ox = ('o', 'x') if self.is_first_player() else ('x', 'o')
        str=''
        for i in range(9):
            if self.prices[i] == 1:
                str += ox[0]
            elif self.enemy_prices[i] == 1:
                str += ox[1]
            else:
                str += '-'
            if i % 3 == 2:
                str += '\n'
        return str

# %%
def random_action(state):
    legal_actions = state.legal_actions()
    return legal_actions[random.randint(0, len(legal_actions)-1)]

# %%
state = State()

while True:

    if state.is_done():
        break

    action = random_action(state)

    state = state.next(action)

    print(state)
# Out:
# -o-
# ---
# ---
#
# xo-
# ---
# ---
#
# xoo
# ---
# ---
#
# xoo
# ---
# --x
#
# xoo
# ---
# -ox
#
# xoo
# ---
# xox
#
# xoo
# --o
# xox
#
# xoo
# -xo
# xox

# %%
def mini_max(state):
    if state.is_lose():
        return -1
    
    if state.is_draw():
        return 0
    
    best_score = -float('inf')
    for action in state.legal_actions():
        score = -mini_max(state.next(action))
        if score > best_score:
            best_score = score

    return best_score

# %%
def mini_max_action(state):

    best_action = 0
    best_score = -float('inf')
    str = ['', '']
    for action in state.legal_actions():
        score = -mini_max(state.next(action))
        if score > best_score:
            best_action = action
            best_score = score

        str[0] = '{}{:2d},'.format(str[0], action)
        str[1] = '{}{:2d},'.format(str[1], score)
    print('action:', str[0], '\nscore: ', str[1], '\n')

    return best_action

# %%
state = State()

while True:

    if state.is_done():
        break

    if state.is_first_player():
        action = mini_max_action(state)
    else:
        action = random_action(state)

    state = state.next(action)

    print(state)
# Out:
# action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# o--
# ---
# ---
#
# o--
# ---
# -x-
#
# action:  1, 2, 3, 4, 5, 6, 8,
# score:   0, 1,-1, 1, 0, 1, 0,
#
# o-o
# ---
# -x-
#
# oxo
# ---
# -x-
#
# action:  3, 4, 5, 6, 8,
# score:  -1, 1,-1,-1,-1,
#
# oxo
# -o-
# -x-
#
# oxo
# xo-
# -x-
#
# action:  5, 6, 8,
# score:   1, 1, 1,
#
# oxo
# xoo
# -x-
#
# oxo
# xoo
# -xx
#
# action:  6,
# score:   1,
#
# oxo
# xoo
# oxx

# %%
def mini_max_plus(state, limit):

    if state.is_lose():
        return -1
    
    if state.is_draw():
        return 0
    
    best_score = -float('inf')
    for action in state.legal_actions():
        score = -mini_max_plus(state.next(action), -best_score)
        if score > best_score:
            best_score = score

        if best_score >= limit:
            return best_score
        
    return best_score

# %%
def alpha_beta(state, alpha, beta):

    if state.is_lose():
        return -1
    
    if state.is_draw():
        return 0
    
    for action in state.legal_actions():
        score = -alpha_beta(state.next(action), -beta, -alpha)
        if score > alpha:
            alpha = score

        if alpha >= beta:
            return alpha
        
    return alpha

# %%
def alpha_beta_action(state):
    best_action = 0
    alpha = -float('inf')
    str = ['', '']
    for action in state.legal_actions():
        score = -alpha_beta(state.next(action), -float('inf'), -alpha)
        if score > alpha:
            best_action = action
            alpha = score

        str[0] = '{}{:2d},'.format(str[0], action)
        str[1] = '{}{:2d},'.format(str[1], score)
    print('action:', str[0], '\nscore: ', str[1], '\n')

    return best_action

# %%
state = State()

while True:

    if state.is_done():
        break

    if state.is_first_player():
        action = alpha_beta_action(state)
    else:
        action = mini_max_action(state)

    state = state.next(action)

    print(state)
# Out:
# action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# o--
# ---
# ---
#
# action:  1, 2, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0,-1,-1,-1,-1,
#
# o--
# -x-
# ---
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# oo-
# -x-
# ---
#
# action:  2, 3, 5, 6, 7, 8,
# score:   0,-1,-1,-1,-1,-1,
#
# oox
# -x-
# ---
#
# action:  3, 5, 6, 7, 8,
# score:  -1,-1, 0, 0, 0,
#
# oox
# -x-
# o--
#
# action:  3, 5, 7, 8,
# score:   0,-1,-1,-1,
#
# oox
# xx-
# o--
#
# action:  5, 7, 8,
# score:   0,-1,-1,
#
# oox
# xxo
# o--
#
# action:  7, 8,
# score:   0, 0,
#
# oox
# xxo
# ox-
#
# action:  8,
# score:   0,
#
# oox
# xxo
# oxo

# %%
def playout(state):
    if state.is_lose():
        return -1
    
    if state.is_draw():
        return 0
    
    return -playout(state.next(random_action(state)))

# %%
def mcs_action(state):

    legal_actions = state.legal_actions()
    values = [0] * len(legal_actions)
    for i, action in enumerate(legal_actions):
        for _ in range(10):
            values[i] += -playout(state.next(action))

    return legal_actions[argmax(values)]

# %%
def argmax(collection, key = None):
    return collection.index(max(collection))

# %%
EP_GAME_COUNT = 100

def first_player_point(ended_state):

    if ended_state.is_lose():
        return 0 if ended_state.is_first_player() else 1
    return 0.5
def play(next_actions):
    state = State()

    while True:
        if state.is_done():
            break

        next_action = next_actions[0] if state.is_first_player() else next_actions[1]
        action = next_action(state)

        state = state.next(action)

    return first_player_point(state)

def evaludate_algorithm_of(label, next_actions):
    total_point = 0
    for i in range(EP_GAME_COUNT):
        if i % 2 == 0:
            total_point += play(next_actions)
        else:
            total_point += 1 - play(list(reversed(next_actions)))

        print('\rEvaluate {}/{}'.format(i+1, EP_GAME_COUNT), end='')
    print('')

    average_point = total_point / EP_GAME_COUNT
    print(label.format(average_point))

next_actions = (mcs_action, random_action)
evaludate_algorithm_of('VS_RANDOM {:3f}', next_actions)


next_actions = (mcs_action, alpha_beta_action)
evaludate_algorithm_of('VS_ALPHABETA {:3f}', next_actions)
# Out:
# Evaluate 100/100
# VS_RANDOM 0.870000
# action:  0, 1, 2, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 6, 8,
# score:  -1, 1, 1, 1, 1, 1,
#
# action:  4, 5, 6, 8,
# score:   1,-1,-1,-1,
#
# action:  5, 6,
# score:  -1, 1,
#
# Evaluate 1/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# action:  3, 5, 6, 7, 8,
# score:  -1,-1, 0, 0, 0,
#
# action:  5, 7, 8,
# score:   0,-1,-1,
#
# action:  8,
# score:   0,
#
# Evaluate 2/100action:  1, 2, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 8,
# score:  -1,-1, 0, 0, 0, 0,
#
# action:  1, 5, 6, 8,
# score:   0, 1,-1,-1,
#
# Evaluate 3/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  3, 4, 5, 7, 8,
# score:  -1, 1, 1, 1, 1,
#
# action:  3, 5, 7,
# score:  -1,-1, 1,
#
# Evaluate 4/100action:  0, 1, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  0, 1, 3, 5, 6, 7,
# score:  -1,-1,-1, 0, 0, 0,
#
# action:  0, 1, 6, 7,
# score:   0, 0, 0, 0,
#
# action:  1, 7,
# score:  -1, 0,
#
# Evaluate 5/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 3, 4, 5, 6, 7, 8,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 5, 7, 8,
# score:  -1, 1, 1, 1, 1,
#
# action:  1, 5, 7,
# score:  -1, 1, 1,
#
# Evaluate 6/100action:  0, 1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 6, 7, 8,
# score:  -1,-1, 0,-1, 0, 0,
#
# action:  1, 6, 7, 8,
# score:  -1, 1, 1, 1,
#
# Evaluate 7/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  3, 4, 5, 6, 8,
# score:  -1, 1, 1, 1, 1,
#
# action:  3, 5, 8,
# score:  -1,-1, 1,
#
# Evaluate 8/100action:  0, 1, 2, 3, 4, 5, 6, 7,
# score:  -1,-1,-1,-1, 0, 0, 0, 0,
#
# action:  0, 1, 2, 3, 5, 6,
# score:  -1,-1,-1,-1,-1, 0,
#
# action:  0, 1, 3, 5,
# score:  -1,-1,-1, 0,
#
# action:  0, 1,
# score:   0, 0,
#
# Evaluate 9/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# action:  3, 5, 6, 7, 8,
# score:  -1,-1, 0, 0, 0,
#
# action:  5, 7, 8,
# score:   0,-1,-1,
#
# action:  8,
# score:   0,
#
# Evaluate 10/100action:  0, 1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 5, 6, 7, 8,
# score:  -1,-1,-1,-1, 0, 0,
#
# action:  2, 5, 6, 8,
# score:  -1, 0,-1,-1,
#
# action:  2, 8,
# score:   0,-1,
#
# Evaluate 11/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# action:  3, 5, 6, 7, 8,
# score:  -1,-1, 0, 0, 0,
#
# action:  3, 7, 8,
# score:   1,-1,-1,
#
# Evaluate 12/100action:  0, 1, 2, 3, 4, 5, 6, 8,
# score:  -1, 0, 0, 0, 0, 0, 0, 0,
#
# action:  0, 2, 4, 5, 6, 8,
# score:  -1,-1,-1,-1, 0, 0,
#
# action:  0, 2, 5, 8,
# score:  -1,-1, 0, 0,
#
# action:  2, 8,
# score:  -1, 0,
#
# Evaluate 13/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 3, 4, 5, 6, 7, 8,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 5, 6, 8,
# score:  -1, 1, 1, 1, 1,
#
# action:  1, 5, 8,
# score:  -1, 1, 1,
#
# Evaluate 14/100action:  0, 1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 6, 7, 8,
# score:  -1,-1, 0,-1, 0, 0,
#
# action:  1, 2, 7, 8,
# score:  -1, 0, 0, 0,
#
# action:  7, 8,
# score:   0,-1,
#
# Evaluate 15/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 7,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 4, 5, 6,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 16/100action:  0, 1, 2, 3, 4, 5, 7, 8,
# score:  -1,-1,-1,-1, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 7, 8,
# score:  -1,-1, 0,-1, 0, 0,
#
# action:  1, 2, 7, 8,
# score:   0, 0, 0, 0,
#
# action:  2, 8,
# score:  -1, 0,
#
# Evaluate 17/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 3, 4, 5, 6, 7, 8,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 5, 7, 8,
# score:  -1, 1, 1, 1, 1,
#
# action:  1, 7, 8,
# score:  -1,-1, 1,
#
# Evaluate 18/100action:  0, 1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 6, 7, 8,
# score:  -1,-1, 0,-1, 0, 0,
#
# action:  1, 2, 7, 8,
# score:  -1, 0, 0, 0,
#
# action:  7, 8,
# score:   0,-1,
#
# Evaluate 19/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 5, 7, 8,
# score:   1,-1,-1,-1,-1,
#
# Evaluate 20/100action:  0, 1, 2, 3, 4, 5, 6, 7,
# score:  -1,-1,-1,-1, 0, 0, 0, 0,
#
# action:  0, 1, 2, 3, 5, 7,
# score:  -1,-1,-1,-1,-1, 0,
#
# action:  0, 2, 3, 5,
# score:   0, 0, 0, 0,
#
# action:  2, 3,
# score:   0,-1,
#
# Evaluate 21/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 4, 5, 6, 7, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 5, 7, 8,
# score:  -1, 1, 1, 1, 1,
#
# action:  2, 5, 7,
# score:  -1, 1, 1,
#
# Evaluate 22/100action:  0, 1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 5, 6, 7, 8,
# score:  -1,-1, 0, 0, 0, 0,
#
# action:  1, 6, 7, 8,
# score:  -1, 0, 0, 0,
#
# action:  7, 8,
# score:   0,-1,
#
# Evaluate 23/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 3, 4, 5, 6, 7, 8,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 5, 7, 8,
# score:  -1, 1, 1, 1, 1,
#
# action:  1, 5, 7,
# score:  -1, 1, 1,
#
# Evaluate 24/100action:  1, 2, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 7, 8,
# score:  -1,-1, 0,-1, 0, 0,
#
# action:  1, 2, 7, 8,
# score:   0, 0, 0, 0,
#
# action:  2, 8,
# score:  -1, 0,
#
# Evaluate 25/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 6, 7, 8,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 6, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 26/100action:  1, 2, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  1, 2, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0,
#
# action:  2, 5, 7, 8,
# score:   1,-1,-1,-1,
#
# Evaluate 27/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  3, 4, 5, 7, 8,
# score:  -1, 1, 1, 1, 1,
#
# action:  3, 5, 7,
# score:  -1,-1, 1,
#
# Evaluate 28/100action:  0, 1, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  0, 3, 5, 6, 7, 8,
# score:   0,-1,-1,-1,-1,-1,
#
# action:  3, 5, 6, 7,
# score:  -1, 0, 0, 0,
#
# action:  6, 7,
# score:   0, 0,
#
# Evaluate 29/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# action:  3, 5, 6, 7, 8,
# score:  -1,-1, 0, 0, 0,
#
# action:  5, 7, 8,
# score:   0,-1,-1,
#
# action:  8,
# score:   0,
#
# Evaluate 30/100action:  0, 1, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  0, 3, 5, 6, 7, 8,
# score:   0,-1,-1,-1,-1,-1,
#
# action:  3, 5, 6, 7,
# score:  -1, 0, 0, 0,
#
# action:  6, 7,
# score:   0, 0,
#
# Evaluate 31/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 6, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 32/100action:  0, 1, 2, 3, 4, 5, 7, 8,
# score:  -1,-1,-1,-1, 0, 0, 0, 0,
#
# action:  0, 1, 2, 3, 7, 8,
# score:  -1, 0, 0, 0, 0, 0,
#
# action:  2, 3, 7, 8,
# score:  -1, 0, 1, 1,
#
# Evaluate 33/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  2, 3, 5, 7, 8,
# score:   1,-1,-1,-1,-1,
#
# Evaluate 34/100action:  0, 1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 8,
# score:   0,-1,-1,-1,-1,-1,
#
# action:  3, 5, 6, 8,
# score:  -1,-1, 0, 0,
#
# action:  5, 8,
# score:   0,-1,
#
# Evaluate 35/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  2, 3, 5, 7, 8,
# score:   1,-1,-1,-1,-1,
#
# Evaluate 36/100action:  0, 1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 3, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0,
#
# action:  1, 3, 7, 8,
# score:  -1, 1, 1, 1,
#
# Evaluate 37/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# action:  3, 5, 6, 7, 8,
# score:  -1,-1, 0, 0, 0,
#
# action:  5, 7, 8,
# score:   0,-1,-1,
#
# action:  8,
# score:   0,
#
# Evaluate 38/100action:  1, 2, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  2, 3, 5, 6, 7, 8,
# score:   0,-1,-1,-1,-1,-1,
#
# action:  3, 5, 7, 8,
# score:   0,-1,-1,-1,
#
# action:  7, 8,
# score:   0, 0,
#
# Evaluate 39/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 5, 7, 8,
# score:   1,-1,-1,-1,-1,
#
# Evaluate 40/100action:  0, 1, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  0, 1, 3, 6, 7, 8,
# score:  -1,-1,-1,-1,-1, 0,
#
# action:  1, 3, 6, 7,
# score:   0,-1,-1,-1,
#
# action:  3, 6,
# score:   0, 0,
#
# Evaluate 41/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 3, 4, 5, 6, 7, 8,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 5, 6, 7, 8,
# score:  -1,-1, 1, 1, 1,
#
# Evaluate 42/100action:  0, 1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 6, 7, 8,
# score:  -1,-1, 0,-1, 0, 0,
#
# action:  1, 2, 7, 8,
# score:  -1, 0, 0, 0,
#
# action:  7, 8,
# score:   0,-1,
#
# Evaluate 43/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 6, 7, 8,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 6, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 44/100action:  0, 1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 7, 8,
# score:  -1, 0, 0, 0, 0, 0,
#
# action:  1, 3, 7, 8,
# score:   1, 1, 1, 1,
#
# Evaluate 45/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  3, 4, 5, 7, 8,
# score:  -1, 1, 1, 1, 1,
#
# action:  3, 5, 7,
# score:  -1,-1, 1,
#
# Evaluate 46/100action:  1, 2, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  1, 2, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0,
#
# action:  2, 5, 7, 8,
# score:   1,-1,-1,-1,
#
# Evaluate 47/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# action:  3, 5, 6, 7, 8,
# score:  -1,-1, 0, 0, 0,
#
# action:  5, 7, 8,
# score:   0,-1,-1,
#
# action:  8,
# score:   0,
#
# Evaluate 48/100action:  0, 1, 2, 3, 4, 5, 7, 8,
# score:  -1,-1,-1,-1, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 7, 8,
# score:  -1,-1, 0,-1, 0, 0,
#
# action:  1, 5, 7, 8,
# score:   1, 1,-1,-1,
#
# action:  5, 8,
# score:   1, 0,
#
# Evaluate 49/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 5, 7, 8,
# score:   1,-1,-1,-1,-1,
#
# Evaluate 50/100action:  0, 1, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  1, 3, 5, 6, 7, 8,
# score:   0,-1,-1,-1,-1,-1,
#
# action:  3, 6, 7, 8,
# score:  -1,-1, 1, 1,
#
# Evaluate 51/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  3, 4, 5, 7, 8,
# score:  -1, 1, 1, 1, 1,
#
# action:  3, 5, 7,
# score:  -1,-1, 1,
#
# Evaluate 52/100action:  0, 1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 5, 6, 7, 8,
# score:  -1,-1,-1,-1, 0, 0,
#
# action:  2, 3, 5, 8,
# score:   0,-1,-1,-1,
#
# action:  5, 8,
# score:   0,-1,
#
# Evaluate 53/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 7,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 4, 5, 6,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 54/100action:  0, 1, 2, 3, 4, 5, 7, 8,
# score:  -1,-1,-1,-1, 0, 0, 0, 0,
#
# action:  0, 2, 3, 5, 7, 8,
# score:   0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 5, 7,
# score:  -1,-1,-1, 0,
#
# action:  3, 5,
# score:  -1, 0,
#
# Evaluate 55/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 5, 7, 8,
# score:   1,-1,-1,-1,-1,
#
# Evaluate 56/100action:  0, 1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 5, 6, 7, 8,
# score:  -1,-1,-1,-1, 0, 0,
#
# action:  2, 3, 5, 8,
# score:   0,-1,-1,-1,
#
# action:  3, 8,
# score:   0,-1,
#
# Evaluate 57/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 4, 5, 6, 7, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  2, 5, 6, 7, 8,
# score:  -1,-1, 1, 1, 1,
#
# Evaluate 58/100action:  1, 2, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 7, 8,
# score:  -1,-1, 0,-1, 0, 0,
#
# action:  1, 2, 7, 8,
# score:   0, 0, 0, 0,
#
# action:  2, 8,
# score:  -1, 0,
#
# Evaluate 59/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 6, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 60/100action:  0, 1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 5, 6, 7, 8,
# score:  -1,-1,-1,-1, 0, 0,
#
# action:  2, 3, 5, 8,
# score:   0,-1,-1,-1,
#
# action:  3, 8,
# score:   0,-1,
#
# Evaluate 61/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# action:  3, 5, 6, 7, 8,
# score:  -1,-1, 0, 0, 0,
#
# action:  5, 7, 8,
# score:   0,-1,-1,
#
# action:  8,
# score:   0,
#
# Evaluate 62/100action:  0, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 5, 6, 7, 8,
# score:  -1,-1,-1,-1, 0, 0,
#
# action:  2, 5, 6, 8,
# score:  -1, 0,-1,-1,
#
# action:  6, 8,
# score:   0,-1,
#
# Evaluate 63/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# action:  3, 5, 6, 7, 8,
# score:  -1,-1, 0, 0, 0,
#
# action:  5, 7, 8,
# score:   0,-1,-1,
#
# action:  8,
# score:   0,
#
# Evaluate 64/100action:  0, 1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 3, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0,
#
# action:  1, 5, 7, 8,
# score:  -1, 0,-1,-1,
#
# action:  7, 8,
# score:   0,-1,
#
# Evaluate 65/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# action:  3, 5, 6, 7, 8,
# score:  -1,-1, 0, 0, 0,
#
# action:  5, 7, 8,
# score:   0,-1,-1,
#
# action:  8,
# score:   0,
#
# Evaluate 66/100action:  0, 1, 2, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 5, 6, 7, 8,
# score:  -1,-1, 0, 0, 0, 0,
#
# action:  1, 6, 7, 8,
# score:  -1, 0, 0, 0,
#
# action:  1, 8,
# score:   0,-1,
#
# Evaluate 67/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  3, 4, 5, 6, 8,
# score:  -1, 1, 1, 1, 1,
#
# action:  3, 5, 8,
# score:  -1,-1, 1,
#
# Evaluate 68/100action:  0, 1, 2, 3, 4, 5, 7, 8,
# score:  -1,-1,-1,-1, 0, 0, 0, 0,
#
# action:  0, 1, 3, 5, 7, 8,
# score:  -1, 0, 0, 0, 0, 0,
#
# action:  0, 3, 5, 8,
# score:  -1,-1,-1, 0,
#
# action:  3, 5,
# score:   0,-1,
#
# Evaluate 69/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  3, 4, 5, 7, 8,
# score:  -1, 1, 1, 1, 1,
#
# action:  3, 5, 8,
# score:  -1,-1, 1,
#
# Evaluate 70/100action:  0, 1, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  1, 3, 5, 6, 7, 8,
# score:   0,-1,-1,-1,-1,-1,
#
# action:  3, 5, 7, 8,
# score:   1,-1, 1,-1,
#
# action:  5, 8,
# score:   1, 0,
#
# Evaluate 71/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# action:  3, 5, 6, 7, 8,
# score:  -1,-1, 0, 0, 0,
#
# action:  5, 7, 8,
# score:   0,-1,-1,
#
# action:  8,
# score:   0,
#
# Evaluate 72/100action:  1, 2, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  1, 3, 5, 6, 7, 8,
# score:   0,-1,-1,-1,-1,-1,
#
# action:  3, 5, 6, 8,
# score:   0, 0, 0, 0,
#
# action:  6, 8,
# score:  -1, 0,
#
# Evaluate 73/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# action:  5, 6, 7,
# score:   0,-1, 1,
#
# Evaluate 74/100action:  0, 1, 2, 3, 4, 5, 7, 8,
# score:  -1,-1,-1,-1, 0, 0, 0, 0,
#
# action:  0, 2, 3, 5, 7, 8,
# score:   0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 5, 7,
# score:  -1,-1,-1, 0,
#
# action:  3, 5,
# score:  -1, 0,
#
# Evaluate 75/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 6, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 76/100action:  0, 1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 5, 6, 7, 8,
# score:  -1,-1,-1,-1, 0, 0,
#
# action:  2, 5, 6, 8,
# score:  -1, 0,-1,-1,
#
# action:  6, 8,
# score:   0,-1,
#
# Evaluate 77/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  2, 3, 5, 7, 8,
# score:   1,-1,-1,-1,-1,
#
# Evaluate 78/100action:  0, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 4, 5, 6, 7, 8,
# score:  -1, 0, 0, 0, 0, 0,
#
# action:  2, 5, 6, 7,
# score:   0, 0, 0, 0,
#
# action:  5, 7,
# score:  -1, 0,
#
# Evaluate 79/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 5, 7, 8,
# score:   1,-1,-1,-1,-1,
#
# Evaluate 80/100action:  0, 1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 5, 6, 7, 8,
# score:  -1,-1,-1,-1, 0, 0,
#
# action:  2, 3, 5, 8,
# score:   0,-1,-1,-1,
#
# action:  5, 8,
# score:   0,-1,
#
# Evaluate 81/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 3, 4, 5, 6, 7, 8,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 5, 6, 7,
# score:  -1,-1, 1, 1, 1,
#
# action:  1, 6, 7,
# score:  -1, 1, 1,
#
# Evaluate 82/100action:  0, 1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 3, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0,
#
# action:  1, 5, 7, 8,
# score:  -1, 0,-1,-1,
#
# action:  7, 8,
# score:   0,-1,
#
# Evaluate 83/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 7,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 4, 5, 7,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 84/100action:  1, 2, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 7, 8,
# score:  -1,-1, 0,-1, 0, 0,
#
# action:  1, 2, 7, 8,
# score:   0, 0, 0, 0,
#
# action:  2, 8,
# score:  -1, 0,
#
# Evaluate 85/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# action:  3, 5, 6, 7, 8,
# score:  -1,-1, 0, 0, 0,
#
# action:  5, 7, 8,
# score:   0,-1,-1,
#
# action:  8,
# score:   0,
#
# Evaluate 86/100action:  0, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 4, 5, 6, 7, 8,
# score:  -1, 0, 0, 0, 0, 0,
#
# action:  2, 5, 6, 7,
# score:   0, 0, 0, 0,
#
# action:  5, 7,
# score:  -1, 0,
#
# Evaluate 87/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 5, 6, 8,
# score:   1,-1,-1,-1,-1,
#
# Evaluate 88/100action:  1, 2, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  1, 3, 5, 6, 7, 8,
# score:   0,-1,-1,-1,-1,-1,
#
# action:  5, 6, 7, 8,
# score:  -1, 0, 1, 1,
#
# Evaluate 89/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  3, 4, 5, 7, 8,
# score:  -1, 1, 1, 1, 1,
#
# action:  3, 5, 7,
# score:  -1,-1, 1,
#
# Evaluate 90/100action:  0, 1, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  0, 1, 3, 5, 6, 8,
# score:  -1,-1, 0, 0, 0, 0,
#
# action:  0, 1, 6, 8,
# score:  -1,-1,-1, 0,
#
# action:  1, 6,
# score:   0,-1,
#
# Evaluate 91/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 3, 4, 5, 6, 7, 8,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 5, 6, 7,
# score:  -1,-1, 1, 1, 1,
#
# action:  1, 4, 7,
# score:  -1, 1, 1,
#
# Evaluate 92/100action:  0, 1, 2, 3, 4, 5, 6, 7,
# score:  -1,-1,-1,-1, 0, 0, 0, 0,
#
# action:  0, 1, 3, 5, 6, 7,
# score:  -1,-1,-1, 0, 0, 0,
#
# action:  0, 1, 6, 7,
# score:   0, 0, 0, 0,
#
# action:  1, 7,
# score:  -1, 0,
#
# Evaluate 93/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 7,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  3, 4, 5, 6, 7,
# score:   0, 0, 0, 1, 1,
#
# action:  4, 5, 7,
# score:   1, 1, 1,
#
# Evaluate 94/100action:  0, 1, 2, 3, 4, 5, 6, 7,
# score:  -1,-1,-1,-1, 0, 0, 0, 0,
#
# action:  0, 1, 2, 3, 6, 7,
# score:  -1,-1, 0, 0,-1, 0,
#
# action:  0, 1, 3, 7,
# score:  -1,-1,-1, 0,
#
# action:  0, 3,
# score:   0, 0,
#
# Evaluate 95/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0,
#
# action:  3, 5, 6, 7, 8,
# score:  -1,-1, 0, 0, 0,
#
# action:  5, 7, 8,
# score:   0,-1,-1,
#
# action:  8,
# score:   0,
#
# Evaluate 96/100action:  0, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 4, 5, 6, 7,
# score:  -1,-1, 0, 0, 0, 0,
#
# action:  2, 3, 6, 7,
# score:   0,-1,-1,-1,
#
# action:  3, 7,
# score:  -1, 0,
#
# Evaluate 97/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 3, 4, 5, 6, 7, 8,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 5, 7, 8,
# score:  -1, 1, 1, 1, 1,
#
# action:  1, 5, 7,
# score:  -1, 1, 1,
#
# Evaluate 98/100action:  0, 1, 2, 3, 4, 6, 7, 8,
# score:  -1,-1, 0, 0, 0, 0, 0, 0,
#
# action:  1, 3, 4, 6, 7, 8,
# score:  -1, 0, 0, 0, 0, 0,
#
# action:  1, 6, 7, 8,
# score:  -1,-1,-1, 0,
#
# action:  6, 7,
# score:  -1, 0,
#
# Evaluate 99/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 7,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  3, 4, 5, 6, 7,
# score:   0, 0, 0, 1, 1,
#
# action:  3, 5, 7,
# score:   1, 1, 1,
#
# Evaluate 100/100
# VS_ALPHABETA 0.245000

# %%
import math

def mcts_action(state):
    class Node:
        def __init__(self, state):
            self.state = state
            self.w = 0
            self.n = 0
            self.child_nodes = None

        def eval(self):
            if self.state.is_done():
                value = -1 if self.state.is_lose() else 0

                self.w += value
                self.n += 1
                return value
            
            if not self.child_nodes:
                value = playout(self.state)

                self.w += value
                self.n += 1

                if self.n == 10:
                    self.expand()
                return value
            else:
                value = -self.next_child_node().eval()

                self.w += value
                self.n += 1
                return value
        
        def expand(self):
            legal_actions = self.state.legal_actions()
            self.child_nodes = []
            for action in legal_actions:
                self.child_nodes.append(Node(self.state.next(action)))

        def next_child_node(self):

            for child_node in self.child_nodes:
                if child_node.n == 0:
                    return child_node
                
            t = 0
            for c in self.child_nodes:
                t += c.n
            ucb1_values = []
            for child_node in self.child_nodes:
                ucb1_values.append(-child_node.w / child_node.n + (2 * math.log(t) / child_node.n) ** .5)

            return self.child_nodes[argmax(ucb1_values)]

    root_node = Node(state)
    root_node.expand()

    for _ in range(100):
        root_node.eval()

    legal_actions = state.legal_actions()
    n_list = []
    for c in root_node.child_nodes:
        n_list.append(c.n)

    return legal_actions[argmax(n_list)]

# %%
EP_GAME_COUNT = 100

def first_player_point(ended_state):

    if ended_state.is_lose():
        return 0 if ended_state.is_first_player() else 1
    return 0.5
def play(next_actions):
    state = State()

    while True:
        if state.is_done():
            break

        next_action = next_actions[0] if state.is_first_player() else next_actions[1]
        action = next_action(state)

        state = state.next(action)

    return first_player_point(state)

def evaludate_algorithm_of(label, next_actions):
    total_point = 0
    for i in range(EP_GAME_COUNT):
        if i % 2 == 0:
            total_point += play(next_actions)
        else:
            total_point += 1 - play(list(reversed(next_actions)))

        print('\rEvaluate {}/{}'.format(i+1, EP_GAME_COUNT), end='')
    print('')

    average_point = total_point / EP_GAME_COUNT
    print(label.format(average_point))

next_actions = (mcts_action, random_action)
evaludate_algorithm_of('VS_RANDOM {:3f}', next_actions)


next_actions = (mcts_action, alpha_beta_action)
evaludate_algorithm_of('VS_ALPHABETA {:3f}', next_actions)
# Out:
# Evaluate 100/100
# VS_RANDOM 0.045000
# action:  0, 1, 2, 3, 4, 6, 7, 8,
# score:  -1,-1, 0, 0, 0, 0, 0, 0,
#
# action:  0, 1, 3, 4, 6, 8,
# score:   1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 6, 8,
# score:   1, 1, 1, 1,
#
# Evaluate 1/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 6, 7, 8,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 4, 6, 7,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 2/100action:  1, 2, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7,
# score:   0, 0, 0, 0, 0, 0,
#
# action:  3, 5, 6, 7,
# score:  -1, 1, 1, 1,
#
# action:  3, 7,
# score:   1, 1,
#
# Evaluate 3/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 4, 5, 6, 7, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 6, 7, 8,
# score:   0, 1, 1, 1, 1,
#
# action:  2, 6, 8,
# score:   1, 1, 1,
#
# action:  8,
# score:   1,
#
# Evaluate 4/100action:  0, 1, 2, 3, 4, 5, 6, 8,
# score:  -1, 0, 0, 0, 0, 0, 0, 0,
#
# action:  0, 3, 4, 5, 6, 8,
# score:  -1,-1,-1,-1, 0, 0,
#
# action:  0, 3, 5, 8,
# score:   0, 0, 0, 0,
#
# action:  3, 5,
# score:   1, 0,
#
# Evaluate 5/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 4, 6, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 6/100action:  0, 1, 2, 3, 4, 5, 6, 7,
# score:  -1,-1,-1,-1, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7,
# score:   0, 0, 0, 0, 0, 0,
#
# action:  2, 5, 6, 7,
# score:  -1,-1, 1, 1,
#
# action:  2, 7,
# score:   1, 1,
#
# Evaluate 7/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 4, 6, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 8/100action:  0, 1, 2, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 4, 5, 6, 7, 8,
# score:  -1, 0, 0, 0, 0, 0,
#
# action:  2, 5, 6, 8,
# score:   1, 1, 1, 1,
#
# action:  6, 8,
# score:   1, 1,
#
# Evaluate 9/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 4, 5, 6, 7, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 6, 7, 8,
# score:   0, 1, 1, 1, 1,
#
# action:  2, 6, 8,
# score:   1, 1, 1,
#
# action:  8,
# score:   1,
#
# Evaluate 10/100action:  0, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 4, 5, 6, 7, 8,
# score:  -1, 0, 0, 0, 0, 0,
#
# action:  2, 6, 7, 8,
# score:   1, 1, 1, 1,
#
# action:  6, 8,
# score:   1, 1,
#
# Evaluate 11/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 7,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 5, 6, 7,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 12/100action:  0, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 4, 5, 7, 8,
# score:  -1,-1, 0, 0, 0, 0,
#
# action:  2, 5, 7, 8,
# score:   0, 0, 0, 1,
#
# Evaluate 13/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 4, 5, 6, 7, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 6, 7, 8,
# score:   0, 1, 1, 1, 1,
#
# action:  2, 6, 8,
# score:   1, 1, 1,
#
# action:  8,
# score:   1,
#
# Evaluate 14/100action:  0, 1, 2, 3, 4, 5, 6, 8,
# score:  -1, 0, 0, 0, 0, 0, 0, 0,
#
# action:  0, 2, 3, 5, 6, 8,
# score:   0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 5, 6,
# score:   1, 1, 1, 1,
#
# Evaluate 15/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 6, 7, 8,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 4, 6, 7,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 16/100action:  0, 1, 2, 3, 4, 6, 7, 8,
# score:  -1,-1, 0, 0, 0, 0, 0, 0,
#
# action:  0, 1, 3, 4, 6, 7,
# score:   1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 6, 7,
# score:   1, 1, 1, 1,
#
# Evaluate 17/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 5, 6, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 18/100action:  0, 1, 2, 3, 4, 6, 7, 8,
# score:  -1,-1, 0, 0, 0, 0, 0, 0,
#
# action:  1, 3, 4, 6, 7, 8,
# score:  -1, 0, 0, 0, 0, 0,
#
# action:  4, 6, 7, 8,
# score:   0, 0, 0, 0,
#
# action:  6, 7,
# score:   1, 0,
#
# Evaluate 19/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 4, 6, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 20/100action:  0, 1, 2, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 7, 8,
# score:   1, 1, 1, 1,
#
# Evaluate 21/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 5, 6, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 22/100action:  0, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 4, 6, 7, 8,
# score:  -1,-1, 0, 1, 1, 1,
#
# action:  2, 3, 4, 8,
# score:  -1, 1, 1, 1,
#
# Evaluate 23/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 4, 5, 6, 7, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 6, 7, 8,
# score:   0, 1, 1, 1, 1,
#
# action:  2, 6, 8,
# score:   1, 1, 1,
#
# action:  8,
# score:   1,
#
# Evaluate 24/100action:  0, 1, 2, 3, 4, 5, 7, 8,
# score:  -1,-1,-1,-1, 0, 0, 0, 0,
#
# action:  0, 1, 3, 5, 7, 8,
# score:  -1, 0, 0, 0, 0, 0,
#
# action:  0, 3, 7, 8,
# score:  -1,-1, 1, 1,
#
# Evaluate 25/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 4, 5, 6, 7, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 6, 7, 8,
# score:   0, 1, 1, 1, 1,
#
# action:  2, 6, 8,
# score:   1, 1, 1,
#
# action:  8,
# score:   1,
#
# Evaluate 26/100action:  0, 1, 2, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 7, 8,
# score:   1, 1, 1, 1,
#
# Evaluate 27/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 28/100action:  0, 1, 2, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 7, 8,
# score:   1, 1, 1, 1,
#
# Evaluate 29/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 6, 7, 8,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 4, 6, 7,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 30/100action:  0, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  3, 4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1, 1,
#
# action:  4, 5, 6, 8,
# score:   1,-1, 1,-1,
#
# action:  6, 8,
# score:   1, 1,
#
# Evaluate 31/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  2, 3, 4, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 32/100action:  0, 1, 2, 3, 4, 5, 7, 8,
# score:  -1,-1,-1,-1, 0, 0, 0, 0,
#
# action:  0, 1, 3, 5, 7, 8,
# score:  -1, 0, 0, 0, 0, 0,
#
# action:  0, 3, 7, 8,
# score:  -1,-1, 1, 1,
#
# Evaluate 33/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 5, 6, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 34/100action:  0, 1, 2, 3, 4, 5, 6, 8,
# score:  -1, 0, 0, 0, 0, 0, 0, 0,
#
# action:  0, 2, 3, 4, 6, 8,
# score:  -1,-1,-1,-1, 0, 0,
#
# action:  0, 2, 3, 4,
# score:  -1, 1, 1, 1,
#
# action:  0, 4,
# score:   1, 1,
#
# Evaluate 35/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 4, 5, 6, 7, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# action:  5, 7, 8,
# score:   1, 1, 1,
#
# Evaluate 36/100action:  1, 2, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7,
# score:   0, 0, 0, 0, 0, 0,
#
# action:  2, 5, 6, 7,
# score:  -1,-1, 1, 1,
#
# action:  2, 7,
# score:   1, 1,
#
# Evaluate 37/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 5, 6, 7,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 38/100action:  0, 1, 2, 3, 4, 6, 7, 8,
# score:  -1,-1, 0, 0, 0, 0, 0, 0,
#
# action:  0, 1, 3, 4, 6, 7,
# score:   1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 4, 6,
# score:   1, 1, 1, 1,
#
# Evaluate 39/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 6, 7, 8,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 4, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 40/100action:  0, 1, 2, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 7, 8,
# score:   1, 1, 1, 1,
#
# Evaluate 41/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 4, 5, 6, 7, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 6, 7, 8,
# score:   0, 1, 1, 1, 1,
#
# action:  2, 6, 8,
# score:   1, 1, 1,
#
# action:  8,
# score:   1,
#
# Evaluate 42/100action:  0, 1, 2, 3, 4, 6, 7, 8,
# score:  -1,-1, 0, 0, 0, 0, 0, 0,
#
# action:  0, 3, 4, 6, 7, 8,
# score:  -1, 0, 0, 0, 0, 0,
#
# action:  0, 4, 6, 7,
# score:   0, 0, 1, 1,
#
# action:  0, 4,
# score:   1, 1,
#
# Evaluate 43/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 4, 6, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 44/100action:  0, 1, 2, 3, 4, 5, 7, 8,
# score:  -1,-1,-1,-1, 0, 0, 0, 0,
#
# action:  0, 1, 3, 5, 7, 8,
# score:  -1, 0, 0, 0, 0, 0,
#
# action:  0, 3, 7, 8,
# score:  -1,-1, 1, 1,
#
# Evaluate 45/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 5, 6, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 46/100action:  0, 1, 2, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 6, 8,
# score:  -1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 5, 8,
# score:   1, 1, 1, 1,
#
# Evaluate 47/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 4, 6, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 48/100action:  0, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  3, 4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1, 1,
#
# action:  4, 5, 6, 8,
# score:   1,-1, 1,-1,
#
# action:  6, 8,
# score:   1, 1,
#
# Evaluate 49/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 50/100action:  0, 1, 2, 3, 4, 6, 7, 8,
# score:  -1,-1, 0, 0, 0, 0, 0, 0,
#
# action:  0, 1, 3, 4, 6, 7,
# score:   1, 1, 1, 1, 1, 1,
#
# action:  3, 4, 6, 7,
# score:   0, 0, 1, 1,
#
# action:  3, 4,
# score:   1, 1,
#
# Evaluate 51/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 52/100action:  0, 1, 2, 3, 4, 5, 6, 7,
# score:  -1,-1,-1,-1, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7,
# score:   0, 0, 0, 0, 0, 0,
#
# action:  2, 5, 6, 7,
# score:  -1,-1, 1, 1,
#
# action:  2, 7,
# score:   1, 1,
#
# Evaluate 53/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 5, 6, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 54/100action:  0, 1, 2, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 4, 5, 6, 7, 8,
# score:  -1, 0, 0, 0, 0, 0,
#
# action:  2, 6, 7, 8,
# score:   1, 1, 1, 1,
#
# action:  6, 8,
# score:   1, 1,
#
# Evaluate 55/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 56/100action:  0, 1, 2, 3, 4, 5, 6, 8,
# score:  -1, 0, 0, 0, 0, 0, 0, 0,
#
# action:  0, 2, 3, 4, 6, 8,
# score:  -1,-1,-1,-1, 0, 0,
#
# action:  0, 2, 3, 8,
# score:  -1,-1, 0, 0,
#
# action:  0, 8,
# score:   1, 0,
#
# Evaluate 57/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 4, 5, 6, 7, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# action:  5, 7, 8,
# score:   1, 1, 1,
#
# Evaluate 58/100action:  0, 1, 2, 3, 4, 5, 6, 8,
# score:  -1, 0, 0, 0, 0, 0, 0, 0,
#
# action:  0, 2, 3, 5, 6, 8,
# score:   0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 6, 8,
# score:   1, 1, 1, 1,
#
# Evaluate 59/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 3, 4, 5, 6, 7, 8,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# action:  5, 7, 8,
# score:   1, 1, 1,
#
# Evaluate 60/100action:  0, 1, 2, 3, 4, 6, 7, 8,
# score:  -1,-1, 0, 0, 0, 0, 0, 0,
#
# action:  0, 1, 3, 4, 6, 7,
# score:   1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 4, 6,
# score:   1, 1, 1, 1,
#
# Evaluate 61/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 4, 5, 6, 7, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 5, 6, 7,
# score:   0, 1, 1, 1, 1,
#
# action:  5, 6, 7,
# score:   1, 1,-1,
#
# Evaluate 62/100action:  0, 1, 2, 3, 4, 5, 6, 7,
# score:  -1,-1,-1,-1, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7,
# score:   0, 0, 0, 0, 0, 0,
#
# action:  2, 5, 6, 7,
# score:  -1,-1, 1, 1,
#
# action:  2, 7,
# score:   1, 1,
#
# Evaluate 63/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 4, 5, 6, 7, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# action:  5, 7, 8,
# score:   1, 1, 1,
#
# Evaluate 64/100action:  0, 1, 2, 3, 4, 5, 6, 7,
# score:  -1,-1,-1,-1, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7,
# score:   0, 0, 0, 0, 0, 0,
#
# action:  3, 5, 6, 7,
# score:  -1, 1, 1, 1,
#
# action:  3, 7,
# score:   1, 1,
#
# Evaluate 65/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 4, 5, 6, 7, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 6, 7, 8,
# score:   0, 1, 1, 1, 1,
#
# action:  2, 6, 8,
# score:   1, 1, 1,
#
# action:  8,
# score:   1,
#
# Evaluate 66/100action:  0, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  3, 4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1, 1,
#
# action:  4, 5, 6, 8,
# score:   1,-1, 1,-1,
#
# action:  6, 8,
# score:   1, 1,
#
# Evaluate 67/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  2, 3, 4, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 68/100action:  0, 1, 2, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 6, 8,
# score:  -1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 6, 8,
# score:   1, 1, 1, 1,
#
# Evaluate 69/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 5, 6, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 70/100action:  0, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  3, 4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1, 1,
#
# action:  4, 5, 6, 8,
# score:   1,-1, 1,-1,
#
# action:  6, 8,
# score:   1, 1,
#
# Evaluate 71/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 6, 7, 8,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 4, 6, 7,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 72/100action:  0, 1, 2, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 4, 5, 6, 7, 8,
# score:  -1, 0, 0, 0, 0, 0,
#
# action:  2, 6, 7, 8,
# score:   1, 1, 1, 1,
#
# action:  6, 8,
# score:   1, 1,
#
# Evaluate 73/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 5, 6, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 74/100action:  0, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  3, 4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1, 1,
#
# action:  4, 5, 6, 8,
# score:   1,-1, 1,-1,
#
# action:  6, 8,
# score:   1, 1,
#
# Evaluate 75/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 5, 6, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 76/100action:  0, 1, 2, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 7, 8,
# score:   1, 1, 1, 1,
#
# Evaluate 77/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 78/100action:  0, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 4, 6, 7, 8,
# score:  -1,-1, 0, 1, 1, 1,
#
# action:  3, 4, 7, 8,
# score:   1, 1, 1, 1,
#
# Evaluate 79/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 5, 6, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 80/100action:  0, 1, 2, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 6, 8,
# score:  -1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 5, 8,
# score:   1, 1, 1, 1,
#
# Evaluate 81/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 82/100action:  0, 1, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  0, 1, 3, 5, 7, 8,
# score:  -1, 0, 0, 0, 0, 0,
#
# action:  0, 3, 7, 8,
# score:  -1,-1, 1, 1,
#
# Evaluate 83/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 84/100action:  0, 1, 2, 3, 4, 6, 7, 8,
# score:  -1,-1, 0, 0, 0, 0, 0, 0,
#
# action:  0, 1, 3, 4, 6, 7,
# score:   1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 4, 7,
# score:   1, 1, 1, 1,
#
# Evaluate 85/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 4, 5, 6, 7, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# action:  5, 7, 8,
# score:   1, 1, 1,
#
# Evaluate 86/100action:  0, 1, 2, 3, 4, 6, 7, 8,
# score:  -1,-1, 0, 0, 0, 0, 0, 0,
#
# action:  0, 1, 3, 4, 6, 7,
# score:   1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 6, 7,
# score:   1, 1, 1, 1,
#
# Evaluate 87/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 88/100action:  0, 1, 2, 3, 4, 5, 6, 8,
# score:  -1, 0, 0, 0, 0, 0, 0, 0,
#
# action:  0, 2, 3, 4, 6, 8,
# score:  -1,-1,-1,-1, 0, 0,
#
# action:  0, 2, 3, 4,
# score:  -1, 1, 1, 1,
#
# action:  0, 4,
# score:   1, 1,
#
# Evaluate 89/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 4, 5, 6, 7, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# action:  5, 7, 8,
# score:   1, 1, 1,
#
# Evaluate 90/100action:  1, 2, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  2, 3, 5, 6, 7, 8,
# score:   0,-1,-1,-1,-1,-1,
#
# action:  3, 5, 6, 8,
# score:   1, 1, 1, 1,
#
# action:  5, 6,
# score:   1, 1,
#
# Evaluate 91/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 7,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 5, 6, 7,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 92/100action:  0, 1, 2, 3, 4, 5, 6, 8,
# score:  -1, 0, 0, 0, 0, 0, 0, 0,
#
# action:  0, 2, 4, 5, 6, 8,
# score:  -1,-1,-1,-1, 0, 0,
#
# action:  0, 2, 4, 5,
# score:   0, 1, 1, 1,
#
# action:  0, 4,
# score:   1, 1,
#
# Evaluate 93/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 5, 6, 8,
# score:   1,-1,-1,-1,-1,
#
# Evaluate 94/100action:  1, 2, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7,
# score:   0, 0, 0, 0, 0, 0,
#
# action:  2, 5, 6, 7,
# score:  -1,-1, 1, 1,
#
# action:  2, 7,
# score:   1, 1,
#
# Evaluate 95/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 6, 7, 8,
# score:  -1, 1, 1, 1, 1, 1, 1,
#
# action:  1, 3, 4, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 96/100action:  0, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  2, 3, 4, 5, 6, 8,
# score:  -1,-1, 1, 1, 1, 1,
#
# action:  3, 5, 6, 8,
# score:   1, 1, 1, 1,
#
# action:  6, 8,
# score:   1, 1,
#
# Evaluate 97/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 4, 5, 6, 7, 8,
# score:   1, 1, 1, 1, 1, 1, 1,
#
# action:  2, 4, 5, 7, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 98/100action:  1, 2, 3, 4, 5, 6, 7, 8,
# score:  -1,-1,-1, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 5, 6, 7,
# score:   0, 0, 0, 0, 0, 0,
#
# action:  2, 5, 6, 7,
# score:  -1,-1, 1, 1,
#
# action:  2, 7,
# score:   1, 1,
#
# Evaluate 99/100action:  0, 1, 2, 3, 4, 5, 6, 7, 8,
# score:   0, 0, 0, 0, 0, 0, 0, 0, 0,
#
# action:  1, 2, 3, 4, 5, 6, 8,
# score:   0, 1, 1, 1, 1, 1, 1,
#
# action:  1, 4, 5, 6, 8,
# score:   1, 1, 1, 1, 1,
#
# Evaluate 100/100
# VS_ALPHABETA 0.000000
